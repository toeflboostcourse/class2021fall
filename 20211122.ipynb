# %% [markdown]
# <a href="https://colab.research.google.com/github/wnyngj/class2021fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [강아지 경찰 아저씨(일본 동요)](https://www.youtube.com/watch?v=othD6L2GTwQ)

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
def phasor_sine(amp, sr, dur, freq, phase):     
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; phase = 0



F = 349.30 
G = 392.08 
A = 440.00 
B = 493.85 
Bb = 466.15 
C = 523.225 
D = 587.27 

s_all = np.empty(0)

# %%
notes = [0, A, F, F, F, A, F, F, F, Bb, Bb, A, A, G, \
         Bb, Bb, A, A, G, G, D, D, C, Bb, A, G, F, \
         F, G, A, A, A, A, F, Bb, Bb, Bb, A, G, \
         G, A, Bb, Bb, Bb, Bb, G, C, C, C, Bb, A]

durs = [2, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.75, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.25, 0.75, 0.25, 0.25, 0.75, 0.25, 0.50, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.25, 0.5, 0.25, 0.25, 0.75, 0.25, 0.50, 0.25, 0.25, 0.25, 0.25, 0.25, \
        0.25, 0.5]

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):    #두개를 zip으로 묶기
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
